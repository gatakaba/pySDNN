# %% [markdown]
# # SDNN

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from pysdnn import SDNN
from pysdnn import utils
plt.rcParams["figure.figsize"] = [12,8]

# %% [markdown]
# ## データ作成

# %%
n_samples=2000
train_X = np.random.uniform(0, 1, size=[n_samples, 2])
train_y = utils.nonaka(train_X)

N = 100
xx, yy = np.meshgrid(np.linspace(0, 1, N), np.linspace(0, 1, N))
test_X = np.c_[np.ravel(xx), np.ravel(yy)]
test_y = utils.nonaka(test_X)

sdnn =SDNN()

# %% [markdown]
# ## 学習

# %%
sdnn.fit(train_X, train_y)
# Out:
# SDNN(code_pattern_dim=100, hidden_layer_num=200, input_division_num=100,
#    reversal_num=1, verbose=False)

# %% [markdown]
# ## 結果の描画

# %%
predict_y=sdnn.predict(test_X)
prediction_y = sdnn.predict(test_X)
plt.pcolor(xx, yy, prediction_y.reshape([N, N]), vmin=-0.2, vmax=1.2, cmap='jet')
plt.colorbar()
